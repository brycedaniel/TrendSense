# %%
import yfinance as yf
import pandas as pd
from datetime import datetime, timedelta
from newspaper import Article
import nltk

# Ensure the required NLTK data is downloaded
nltk.download('punkt')

def fetch_article_summary(link):
    """
    Fetch and summarize the article content from a URL.
    """
    try:
        # Use Newspaper3k with headers
        article = Article(link)
        article.download()
        article.parse()
        article.nlp()
        return article.summary
    except Exception as e:
        print(f"[ERROR] Newspaper3k failed for {link}: {str(e)}. Falling back to BeautifulSoup.")

        # Fallback to BeautifulSoup
        try:
            response = requests.get(link, headers={'User-Agent': 'Mozilla/5.0'})
            response.raise_for_status()
            soup = BeautifulSoup(response.content, "html.parser")
            paragraphs = soup.find_all("p")
            content = " ".join([p.get_text() for p in paragraphs])
            return content[:500] + "..." if len(content) > 500 else content
        except Exception as bs_error:
            print(f"[ERROR] BeautifulSoup also failed for {link}: {str(bs_error)}")
            return "No summary available."




def get_market_news(tickers):
    """
    Fetch market news for the current day, capturing all available fields and generating summaries.
    Only processes news items with 'type' set to 'story'.
    """
    all_news = []
    today = datetime.now().date()
    one_day_ago = today - timedelta(days=1)

    for ticker in tickers:
        stock = yf.Ticker(ticker)

        try:
            news = stock.news
            for item in news:
                try:
                    publish_timestamp = item.get('providerPublishTime', 0)
                    publish_date = datetime.fromtimestamp(publish_timestamp).date()

                    # Filter news to include only today's and yesterday's articles
                    if publish_date >= one_day_ago:
                        # Only summarize articles with type 'story'
                        if item.get('type', '').lower() == 'story':
                            link = item.get('link', '')
                            summary = fetch_article_summary(link) if link else "No summary available."

                            news_item = {
                                'ticker': ticker,
                                'title': item.get('title', ''),
                                'publisher': item.get('publisher', ''),
                                'link': link,
                                'publish_date': datetime.fromtimestamp(publish_timestamp),
                                'summary': summary,  # Include the generated summary
                                'type': item.get('type', ''),  # Original type from Yahoo API
                                'related_tickers': ', '.join(item.get('relatedTickers', [])),  # Comma-separated related tickers
                            }
                            all_news.append(news_item)
                        else:
                            print(f"[INFO] Skipping non-story type: {item.get('type', '')}")
                except Exception as news_item_error:
                    print(f"[ERROR] Error processing news item: {news_item_error}")

        except Exception as e:
            print(f"[ERROR] Error retrieving news for {ticker}: {str(e)}")

    print(f"[INFO] Fetched {len(all_news)} news articles.")
    return pd.DataFrame(all_news)


def save_to_csv(df, output_dir="market_news"):
    """
    Save processed news data to a CSV file locally.
    """
    try:
        if df.empty:
            print("[INFO] No news data to save.")
            return None

        os.makedirs(output_dir, exist_ok=True)
        filename = f"market_news_{datetime.now().strftime('%Y%m%d_%H%M%S')}.csv"
        filepath = os.path.join(output_dir, filename)
        df.to_csv(filepath, index=False, encoding="utf-8")
        print(f"[INFO] News data saved locally at: {filepath}")
        return filepath
    except Exception as e:
        print(f"[ERROR] Failed to save CSV: {str(e)}")
        return None


def main():
    """
    Main function for fetching and saving market news locally.
    """
    try:
        # Fetch general market news
        indices = ['^IXIC', '^DJI', '^RUT', '^GSPC']
        market_news = get_market_news(tickers=indices)
        if not market_news.empty:
            market_news['category'] = 'General'  # Add category for general market

        # Fetch tech stock news
        tech_stocks = ['AAPL', 'GOOGL', 'MSFT']
        tech_news = get_market_news(tickers=tech_stocks)
        if not tech_news.empty:
            tech_news['category'] = 'Tech'  # Add category for tech stocks

        # Combine news
        combined_news = pd.concat([market_news, tech_news], ignore_index=True)

        # Save to CSV locally
        if not combined_news.empty:
            save_to_csv(combined_news)
        else:
            print("[INFO] No news data to save.")
    except Exception as e:
        print(f"[ERROR] Error in main function: {e}")


if __name__ == "__main__":
    main()
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\BryceDaniel\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [INFO] Skipping non-story type: VIDEO
# [INFO] Skipping non-story type: VIDEO
# [ERROR] Newspaper3k failed for https://finance.yahoo.com/news/equities-mostly-rise-markets-analyze-214815922.html:
# **********************************************************************
#   Resource punkt_tab not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('punkt_tab')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load tokenizers/punkt_tab/english/
#
#   Searched in:
#     - 'C:\\Users\\BryceDaniel/nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\share\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\lib\\nltk_data'
#     - 'C:\\Users\\BryceDaniel\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************
# . Falling back to BeautifulSoup.
# [ERROR] Newspaper3k failed for https://finance.yahoo.com/news/major-us-stock-indexes-fared-212104497.html:
# **********************************************************************
#   Resource punkt_tab not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('punkt_tab')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load tokenizers/punkt_tab/english/
#
#   Searched in:
#     - 'C:\\Users\\BryceDaniel/nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\share\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\lib\\nltk_data'
#     - 'C:\\Users\\BryceDaniel\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************
# . Falling back to BeautifulSoup.
# [INFO] Skipping non-story type: VIDEO
# [ERROR] Newspaper3k failed for https://finance.yahoo.com/news/live/stock-market-today-dow-sp-500-jump-after-nvidia-earnings-while-alphabet-tumbles-172831555.html:
# **********************************************************************
#   Resource punkt_tab not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('punkt_tab')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load tokenizers/punkt_tab/english/
#
#   Searched in:
#     - 'C:\\Users\\BryceDaniel/nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\share\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\lib\\nltk_data'
#     - 'C:\\Users\\BryceDaniel\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************
# . Falling back to BeautifulSoup.
# [ERROR] Newspaper3k failed for https://finance.yahoo.com/m/bc3791e1-8258-3524-aba5-23d8ff3d53fa/s%26p-500-marks-4th-day-of.html:
# **********************************************************************
#   Resource punkt_tab not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('punkt_tab')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load tokenizers/punkt_tab/english/
#
#   Searched in:
#     - 'C:\\Users\\BryceDaniel/nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\share\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\lib\\nltk_data'
#     - 'C:\\Users\\BryceDaniel\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************
# . Falling back to BeautifulSoup.
# [ERROR] Newspaper3k failed for https://finance.yahoo.com/news/equities-higher-traders-analyze-nvidia-205054461.html:
# **********************************************************************
#   Resource punkt_tab not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('punkt_tab')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load tokenizers/punkt_tab/english/
#
#   Searched in:
#     - 'C:\\Users\\BryceDaniel/nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\share\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\lib\\nltk_data'
#     - 'C:\\Users\\BryceDaniel\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************
# . Falling back to BeautifulSoup.
# [ERROR] Newspaper3k failed for https://finance.yahoo.com/m/ea8ab46f-7aa0-3d99-8838-87f45cfdf037/nvidia-earnings-adjust.html:
# **********************************************************************
#   Resource punkt_tab not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('punkt_tab')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load tokenizers/punkt_tab/english/
#
#   Searched in:
#     - 'C:\\Users\\BryceDaniel/nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\share\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\lib\\nltk_data'
#     - 'C:\\Users\\BryceDaniel\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************
# . Falling back to BeautifulSoup.
# [INFO] Skipping non-story type: VIDEO
# [INFO] Skipping non-story type: VIDEO
# [ERROR] Newspaper3k failed for https://finance.yahoo.com/news/major-us-stock-indexes-fared-212104497.html:
# **********************************************************************
#   Resource punkt_tab not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('punkt_tab')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load tokenizers/punkt_tab/english/
#
#   Searched in:
#     - 'C:\\Users\\BryceDaniel/nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\share\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\lib\\nltk_data'
#     - 'C:\\Users\\BryceDaniel\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************
# . Falling back to BeautifulSoup.
# [INFO] Skipping non-story type: VIDEO
# [ERROR] Newspaper3k failed for https://finance.yahoo.com/news/live/stock-market-today-dow-sp-500-jump-after-nvidia-earnings-while-alphabet-tumbles-172831555.html:
# **********************************************************************
#   Resource punkt_tab not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('punkt_tab')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load tokenizers/punkt_tab/english/
#
#   Searched in:
#     - 'C:\\Users\\BryceDaniel/nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\share\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\lib\\nltk_data'
#     - 'C:\\Users\\BryceDaniel\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************
# . Falling back to BeautifulSoup.
# [ERROR] Newspaper3k failed for https://finance.yahoo.com/m/bc3791e1-8258-3524-aba5-23d8ff3d53fa/s%26p-500-marks-4th-day-of.html:
# **********************************************************************
#   Resource punkt_tab not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('punkt_tab')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load tokenizers/punkt_tab/english/
#
#   Searched in:
#     - 'C:\\Users\\BryceDaniel/nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\share\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\lib\\nltk_data'
#     - 'C:\\Users\\BryceDaniel\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************
# . Falling back to BeautifulSoup.
# [ERROR] Newspaper3k failed for https://finance.yahoo.com/m/9aaf159c-7039-30a4-8f6c-0e91bc09a3a4/the-dow-jumped-more-than-500.html:
# **********************************************************************
#   Resource punkt_tab not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('punkt_tab')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load tokenizers/punkt_tab/english/
#
#   Searched in:
#     - 'C:\\Users\\BryceDaniel/nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\share\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\lib\\nltk_data'
#     - 'C:\\Users\\BryceDaniel\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************
# . Falling back to BeautifulSoup.
# [ERROR] Newspaper3k failed for https://finance.yahoo.com/news/major-us-stock-indexes-fared-212104497.html:
# **********************************************************************
#   Resource punkt_tab not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('punkt_tab')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load tokenizers/punkt_tab/english/
#
#   Searched in:
#     - 'C:\\Users\\BryceDaniel/nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\share\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\lib\\nltk_data'
#     - 'C:\\Users\\BryceDaniel\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************
# . Falling back to BeautifulSoup.
# [INFO] Skipping non-story type: VIDEO
# [ERROR] Newspaper3k failed for https://finance.yahoo.com/news/sell-european-wax-center-ewcz-153114931.html:
# **********************************************************************
#   Resource punkt_tab not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('punkt_tab')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load tokenizers/punkt_tab/english/
#
#   Searched in:
#     - 'C:\\Users\\BryceDaniel/nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\share\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\lib\\nltk_data'
#     - 'C:\\Users\\BryceDaniel\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************
# . Falling back to BeautifulSoup.
# [ERROR] Newspaper3k failed for https://finance.yahoo.com/news/does-gcm-grosvenor-inc-gcmg-152749296.html:
# **********************************************************************
#   Resource punkt_tab not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('punkt_tab')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load tokenizers/punkt_tab/english/
#
#   Searched in:
#     - 'C:\\Users\\BryceDaniel/nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\share\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\lib\\nltk_data'
#     - 'C:\\Users\\BryceDaniel\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************
# . Falling back to BeautifulSoup.
# [ERROR] Newspaper3k failed for https://finance.yahoo.com/news/baron-small-cap-fund-sold-152321612.html:
# **********************************************************************
#   Resource punkt_tab not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('punkt_tab')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load tokenizers/punkt_tab/english/
#
#   Searched in:
#     - 'C:\\Users\\BryceDaniel/nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\share\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\lib\\nltk_data'
#     - 'C:\\Users\\BryceDaniel\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************
# . Falling back to BeautifulSoup.
# [ERROR] Newspaper3k failed for https://finance.yahoo.com/news/baron-small-cap-fund-sold-151301575.html:
# **********************************************************************
#   Resource punkt_tab not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('punkt_tab')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load tokenizers/punkt_tab/english/
#
#   Searched in:
#     - 'C:\\Users\\BryceDaniel/nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\share\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\lib\\nltk_data'
#     - 'C:\\Users\\BryceDaniel\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************
# . Falling back to BeautifulSoup.
# [ERROR] Newspaper3k failed for https://finance.yahoo.com/news/retain-conviction-icon-plc-iclr-151109184.html:
# **********************************************************************
#   Resource punkt_tab not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('punkt_tab')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load tokenizers/punkt_tab/english/
#
#   Searched in:
#     - 'C:\\Users\\BryceDaniel/nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\share\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\lib\\nltk_data'
#     - 'C:\\Users\\BryceDaniel\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************
# . Falling back to BeautifulSoup.
# [ERROR] Newspaper3k failed for https://finance.yahoo.com/news/baron-small-cap-fund-increased-143901316.html:
# **********************************************************************
#   Resource punkt_tab not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('punkt_tab')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load tokenizers/punkt_tab/english/
#
#   Searched in:
#     - 'C:\\Users\\BryceDaniel/nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\share\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\lib\\nltk_data'
#     - 'C:\\Users\\BryceDaniel\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************
# . Falling back to BeautifulSoup.
# [ERROR] Newspaper3k failed for https://finance.yahoo.com/news/gold-surges-euro-sags-broader-022920767.html:
# **********************************************************************
#   Resource punkt_tab not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('punkt_tab')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load tokenizers/punkt_tab/english/
#
#   Searched in:
#     - 'C:\\Users\\BryceDaniel/nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\share\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\lib\\nltk_data'
#     - 'C:\\Users\\BryceDaniel\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************
# . Falling back to BeautifulSoup.
# [ERROR] Newspaper3k failed for https://finance.yahoo.com/news/asian-equities-climb-wall-street-224100620.html:
# **********************************************************************
#   Resource punkt_tab not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('punkt_tab')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load tokenizers/punkt_tab/english/
#
#   Searched in:
#     - 'C:\\Users\\BryceDaniel/nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\share\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\lib\\nltk_data'
#     - 'C:\\Users\\BryceDaniel\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************
# . Falling back to BeautifulSoup.
# [ERROR] Newspaper3k failed for https://finance.yahoo.com/m/ea8ab46f-7aa0-3d99-8838-87f45cfdf037/nvidia-earnings-adjust.html:
# **********************************************************************
#   Resource punkt_tab not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('punkt_tab')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load tokenizers/punkt_tab/english/
#
#   Searched in:
#     - 'C:\\Users\\BryceDaniel/nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\share\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\lib\\nltk_data'
#     - 'C:\\Users\\BryceDaniel\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************
# . Falling back to BeautifulSoup.
# [ERROR] Newspaper3k failed for https://finance.yahoo.com/news/analysis-trumps-return-could-extend-001734422.html:
# **********************************************************************
#   Resource punkt_tab not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('punkt_tab')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load tokenizers/punkt_tab/english/
#
#   Searched in:
#     - 'C:\\Users\\BryceDaniel/nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\share\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\lib\\nltk_data'
#     - 'C:\\Users\\BryceDaniel\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************
# . Falling back to BeautifulSoup.
# [ERROR] Newspaper3k failed for https://finance.yahoo.com/m/b3d2d9f4-28f5-3b26-8ded-edc81b65b6c8/russia%E2%80%99s-nuclear-threats.html:
# **********************************************************************
#   Resource punkt_tab not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('punkt_tab')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load tokenizers/punkt_tab/english/
#
#   Searched in:
#     - 'C:\\Users\\BryceDaniel/nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\share\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\lib\\nltk_data'
#     - 'C:\\Users\\BryceDaniel\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************
# . Falling back to BeautifulSoup.
# [ERROR] Newspaper3k failed for https://finance.yahoo.com/m/30bb3a48-3560-3bf8-877f-686057aa4d63/texas-pacific-land-will-join.html:
# **********************************************************************
#   Resource punkt_tab not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('punkt_tab')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load tokenizers/punkt_tab/english/
#
#   Searched in:
#     - 'C:\\Users\\BryceDaniel/nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\share\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\lib\\nltk_data'
#     - 'C:\\Users\\BryceDaniel\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************
# . Falling back to BeautifulSoup.
# [ERROR] Newspaper3k failed for https://finance.yahoo.com/news/prologis-pld-stock-drops-despite-230003920.html:
# **********************************************************************
#   Resource punkt_tab not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('punkt_tab')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load tokenizers/punkt_tab/english/
#
#   Searched in:
#     - 'C:\\Users\\BryceDaniel/nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\share\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\lib\\nltk_data'
#     - 'C:\\Users\\BryceDaniel\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************
# . Falling back to BeautifulSoup.
# [INFO] Skipping non-story type: VIDEO
# [INFO] Fetched 24 news articles.
# [ERROR] Newspaper3k failed for https://finance.yahoo.com/m/a1e3478f-befb-39a4-aeab-f13ee3fb7f10/warren-buffett-just-sold-3.html:
# **********************************************************************
#   Resource punkt_tab not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('punkt_tab')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load tokenizers/punkt_tab/english/
#
#   Searched in:
#     - 'C:\\Users\\BryceDaniel/nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\share\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\lib\\nltk_data'
#     - 'C:\\Users\\BryceDaniel\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************
# . Falling back to BeautifulSoup.
# [ERROR] Newspaper3k failed for https://finance.yahoo.com/m/30a1d1b9-4436-3500-9b44-57253c8ab09d/apple-is-reportedly-building.html:
# **********************************************************************
#   Resource punkt_tab not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('punkt_tab')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load tokenizers/punkt_tab/english/
#
#   Searched in:
#     - 'C:\\Users\\BryceDaniel/nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\share\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\lib\\nltk_data'
#     - 'C:\\Users\\BryceDaniel\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************
# . Falling back to BeautifulSoup.
# [ERROR] Newspaper3k failed for https://finance.yahoo.com/news/apple-readies-more-conversational-siri-210002525.html:
# **********************************************************************
#   Resource punkt_tab not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('punkt_tab')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load tokenizers/punkt_tab/english/
#
#   Searched in:
#     - 'C:\\Users\\BryceDaniel/nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\share\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\lib\\nltk_data'
#     - 'C:\\Users\\BryceDaniel\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************
# . Falling back to BeautifulSoup.
# [ERROR] Newspaper3k failed for https://finance.yahoo.com/m/4205eaa9-f620-3a0b-a81a-0e82c7c9fd0b/magnificent-seven-stocks%3A.html:
# **********************************************************************
#   Resource punkt_tab not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('punkt_tab')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load tokenizers/punkt_tab/english/
#
#   Searched in:
#     - 'C:\\Users\\BryceDaniel/nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\share\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\lib\\nltk_data'
#     - 'C:\\Users\\BryceDaniel\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************
# . Falling back to BeautifulSoup.
# [ERROR] Newspaper3k failed for https://finance.yahoo.com/m/1fcdf03f-54ff-313b-a524-4deba02eb98e/whatsapp-rolls-out-voice.html:
# **********************************************************************
#   Resource punkt_tab not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('punkt_tab')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load tokenizers/punkt_tab/english/
#
#   Searched in:
#     - 'C:\\Users\\BryceDaniel/nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\share\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\lib\\nltk_data'
#     - 'C:\\Users\\BryceDaniel\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************
# . Falling back to BeautifulSoup.
# [ERROR] Newspaper3k failed for https://finance.yahoo.com/m/09bfc624-af25-3a02-aa0a-c1d35149d609/the-doj-google-fight-comes.html:
# **********************************************************************
#   Resource punkt_tab not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('punkt_tab')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load tokenizers/punkt_tab/english/
#
#   Searched in:
#     - 'C:\\Users\\BryceDaniel/nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\share\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\lib\\nltk_data'
#     - 'C:\\Users\\BryceDaniel\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************
# . Falling back to BeautifulSoup.
# [ERROR] Newspaper3k failed for https://finance.yahoo.com/m/828ce92d-c83b-3882-b8d8-c39c5c3bf7fa/planned-age-verification-bill.html:
# **********************************************************************
#   Resource punkt_tab not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('punkt_tab')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load tokenizers/punkt_tab/english/
#
#   Searched in:
#     - 'C:\\Users\\BryceDaniel/nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\share\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\lib\\nltk_data'
#     - 'C:\\Users\\BryceDaniel\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************
# . Falling back to BeautifulSoup.
# [ERROR] Newspaper3k failed for https://finance.yahoo.com/m/ac2cf090-ce97-3e1d-b5e9-a3962f1681ab/doj-seeks-google-sale-of.html:
# **********************************************************************
#   Resource punkt_tab not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('punkt_tab')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load tokenizers/punkt_tab/english/
#
#   Searched in:
#     - 'C:\\Users\\BryceDaniel/nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\share\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\lib\\nltk_data'
#     - 'C:\\Users\\BryceDaniel\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************
# . Falling back to BeautifulSoup.
# [ERROR] Newspaper3k failed for https://finance.yahoo.com/m/8cd900de-5cfb-3f21-b0f6-4966fc9da30b/dow-jones-futures%3A-bulls-run.html:
# **********************************************************************
#   Resource punkt_tab not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('punkt_tab')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load tokenizers/punkt_tab/english/
#
#   Searched in:
#     - 'C:\\Users\\BryceDaniel/nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\share\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\lib\\nltk_data'
#     - 'C:\\Users\\BryceDaniel\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************
# . Falling back to BeautifulSoup.
# [ERROR] Newspaper3k failed for https://finance.yahoo.com/m/6872f31c-b9ed-3f52-8010-7943ff16c265/google-could-be-forced-to.html:
# **********************************************************************
#   Resource punkt_tab not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('punkt_tab')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load tokenizers/punkt_tab/english/
#
#   Searched in:
#     - 'C:\\Users\\BryceDaniel/nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\share\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\lib\\nltk_data'
#     - 'C:\\Users\\BryceDaniel\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************
# . Falling back to BeautifulSoup.
# [ERROR] Newspaper3k failed for https://finance.yahoo.com/news/google-stock-hammered-doj-calls-231412377.html:
# **********************************************************************
#   Resource punkt_tab not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('punkt_tab')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load tokenizers/punkt_tab/english/
#
#   Searched in:
#     - 'C:\\Users\\BryceDaniel/nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\share\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\lib\\nltk_data'
#     - 'C:\\Users\\BryceDaniel\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************
# . Falling back to BeautifulSoup.
# [INFO] Skipping non-story type: VIDEO
# [ERROR] Newspaper3k failed for https://finance.yahoo.com/news/alphabet-insider-sold-shares-worth-220342077.html:
# **********************************************************************
#   Resource punkt_tab not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('punkt_tab')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load tokenizers/punkt_tab/english/
#
#   Searched in:
#     - 'C:\\Users\\BryceDaniel/nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\share\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\lib\\nltk_data'
#     - 'C:\\Users\\BryceDaniel\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************
# . Falling back to BeautifulSoup.
# [ERROR] Newspaper3k failed for https://finance.yahoo.com/m/73e91fca-5b4e-3edd-99e6-afe80e10c1c4/s%26p-500-gains-and-losses.html:
# **********************************************************************
#   Resource punkt_tab not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('punkt_tab')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load tokenizers/punkt_tab/english/
#
#   Searched in:
#     - 'C:\\Users\\BryceDaniel/nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\share\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\lib\\nltk_data'
#     - 'C:\\Users\\BryceDaniel\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************
# . Falling back to BeautifulSoup.
# [ERROR] Newspaper3k failed for https://finance.yahoo.com/m/d0b6d9d7-8a7f-36c7-a405-27a6c0f7684f/these-stocks-moved-the-most.html:
# **********************************************************************
#   Resource punkt_tab not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('punkt_tab')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load tokenizers/punkt_tab/english/
#
#   Searched in:
#     - 'C:\\Users\\BryceDaniel/nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\share\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\lib\\nltk_data'
#     - 'C:\\Users\\BryceDaniel\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************
# . Falling back to BeautifulSoup.
# [ERROR] Newspaper3k failed for https://finance.yahoo.com/news/us-equities-markets-end-higher-210308890.html:
# **********************************************************************
#   Resource punkt_tab not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('punkt_tab')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load tokenizers/punkt_tab/english/
#
#   Searched in:
#     - 'C:\\Users\\BryceDaniel/nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\share\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\lib\\nltk_data'
#     - 'C:\\Users\\BryceDaniel\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************
# . Falling back to BeautifulSoup.
# [ERROR] Newspaper3k failed for https://finance.yahoo.com/m/4205eaa9-f620-3a0b-a81a-0e82c7c9fd0b/magnificent-seven-stocks%3A.html:
# **********************************************************************
#   Resource punkt_tab not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('punkt_tab')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load tokenizers/punkt_tab/english/
#
#   Searched in:
#     - 'C:\\Users\\BryceDaniel/nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\share\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\lib\\nltk_data'
#     - 'C:\\Users\\BryceDaniel\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************
# . Falling back to BeautifulSoup.
# [ERROR] Newspaper3k failed for https://finance.yahoo.com/m/f32d8a60-f334-3927-8e7e-5f0efac6ff63/nvidia-earnings-were-a.html:
# **********************************************************************
#   Resource punkt_tab not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('punkt_tab')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load tokenizers/punkt_tab/english/
#
#   Searched in:
#     - 'C:\\Users\\BryceDaniel/nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\share\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\lib\\nltk_data'
#     - 'C:\\Users\\BryceDaniel\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************
# . Falling back to BeautifulSoup.
# [ERROR] Newspaper3k failed for https://finance.yahoo.com/news/microsoft-corporation-msft-ai-backed-202426239.html:
# **********************************************************************
#   Resource punkt_tab not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('punkt_tab')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load tokenizers/punkt_tab/english/
#
#   Searched in:
#     - 'C:\\Users\\BryceDaniel/nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\share\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\lib\\nltk_data'
#     - 'C:\\Users\\BryceDaniel\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************
# . Falling back to BeautifulSoup.
# [ERROR] Newspaper3k failed for https://finance.yahoo.com/m/5c9be3a1-83cf-3413-95f2-31e741a73558/why-mongodb-stock-surged-today.html:
# **********************************************************************
#   Resource punkt_tab not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('punkt_tab')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load tokenizers/punkt_tab/english/
#
#   Searched in:
#     - 'C:\\Users\\BryceDaniel/nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\share\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\lib\\nltk_data'
#     - 'C:\\Users\\BryceDaniel\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************
# . Falling back to BeautifulSoup.
# [ERROR] Newspaper3k failed for https://finance.yahoo.com/news/nvidia-says-next-gen-blackwell-chip-sales-will-top-prior-forecasts-calming-delay-worries-194453395.html:
# **********************************************************************
#   Resource punkt_tab not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('punkt_tab')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load tokenizers/punkt_tab/english/
#
#   Searched in:
#     - 'C:\\Users\\BryceDaniel/nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\share\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\lib\\nltk_data'
#     - 'C:\\Users\\BryceDaniel\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************
# . Falling back to BeautifulSoup.
# [ERROR] Newspaper3k failed for https://finance.yahoo.com/news/advanced-micro-devices-inc-amd-173829116.html:
# **********************************************************************
#   Resource punkt_tab not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('punkt_tab')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load tokenizers/punkt_tab/english/
#
#   Searched in:
#     - 'C:\\Users\\BryceDaniel/nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\share\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\lib\\nltk_data'
#     - 'C:\\Users\\BryceDaniel\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************
# . Falling back to BeautifulSoup.
# [ERROR] Newspaper3k failed for https://finance.yahoo.com/m/ac2cf090-ce97-3e1d-b5e9-a3962f1681ab/doj-seeks-google-sale-of.html:
# **********************************************************************
#   Resource punkt_tab not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('punkt_tab')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load tokenizers/punkt_tab/english/
#
#   Searched in:
#     - 'C:\\Users\\BryceDaniel/nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\share\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\lib\\nltk_data'
#     - 'C:\\Users\\BryceDaniel\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************
# . Falling back to BeautifulSoup.
# [ERROR] Newspaper3k failed for https://finance.yahoo.com/news/silicon-valley-billionaire-warns-absolutely-165707051.html:
# **********************************************************************
#   Resource punkt_tab not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('punkt_tab')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load tokenizers/punkt_tab/english/
#
#   Searched in:
#     - 'C:\\Users\\BryceDaniel/nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\share\\nltk_data'
#     - 'c:\\Users\\BryceDaniel\\AppData\\Local\\Programs\\Python\\Python312\\lib\\nltk_data'
#     - 'C:\\Users\\BryceDaniel\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************
# . Falling back to BeautifulSoup.
# [INFO] Fetched 23 news articles.
# [INFO] News data saved locally at: market_news\market_news_20241121_200244.csv
